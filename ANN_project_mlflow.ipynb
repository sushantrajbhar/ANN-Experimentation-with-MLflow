# %% [markdown]
# ### Compare runs, choose a model, and deploy it to a REST API
#
# In this quickstart, you will:
#
# - Run a hyperparameter sweep on a training script
#
# - Compare the results of the runs in the MLflow UI
#
# - Choose the best run and register it as a model
#
# - Deploy the model to a REST API
#
# - Build a container image suitable for deployment to a cloud platform

# %%
import keras
import numpy as np
import pandas as pd
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe    #helps hyperparameter tuning for ANN
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import mlflow 
from mlflow.models import infer_signature

# %%
## load the dataset
data=pd.read_csv(
    "https://raw.githubusercontent.com/mlflow/mlflow/master/tests/datasets/winequality-white.csv",
    sep=";",
)
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
## Split the data into training,validation and test sets

train,test=train_test_split(data,test_size=0.25,random_state=42)
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2835            6.3              0.25         0.22            3.30      0.048
# 1157            7.8              0.30         0.29           16.85      0.054
# 744             7.4              0.38         0.27            7.50      0.041
# 1448            7.4              0.16         0.49            1.20      0.055
# 3338            7.2              0.27         0.28           15.20      0.046
# ...             ...               ...          ...             ...        ...
# 4426            6.2              0.21         0.52            6.50      0.047
# 466             7.0              0.14         0.32            9.00      0.039
# 3092            7.6              0.27         0.52            3.20      0.043
# 3772            6.3              0.24         0.29           13.70      0.035
# 860             8.1              0.27         0.35            1.70      0.030
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2835                 41.0                 161.0  0.99256  3.16       0.50
# 1157                 23.0                 135.0  0.99980  3.16       0.38
# 744                  24.0                 160.0  0.99535  3.17       0.43
# 1448                 18.0                 150.0  0.99170  3.23       0.47
# 3338                  6.0                  41.0  0.99665  3.17       0.39
# ...                   ...                   ...      ...   ...        ...
# 4426                 28.0                 123.0  0.99418  3.22       0.49
# 466                  54.0                 141.0  0.99560  3.22       0.43
# 3092                 28.0                 152.0  0.99129  3.02       0.53
# 3772                 53.0                 134.0  0.99567  3.17       0.38
# 860                  38.0                 103.0  0.99255  3.22       0.63
#
#       alcohol  quality
# 2835     10.5        6
# 1157      9.0        6
# 744      10.0        5
# 1448     11.2        6
# 3338     10.9        6
# ...       ...      ...
# 4426      9.9        6
# 466       9.4        6
# 3092     11.4        6
# 3772     10.6        6
# 860      10.4        8
#
# [3673 rows x 12 columns]

# %%
train[['quality']].values.ravel()
# Out:
# array([6, 6, 5, ..., 6, 6, 8])

# %%
train_x=train.drop(['quality'],axis=1).values
train_y=train[['quality']].values.ravel()

## test dataset
test_x=test.drop(['quality'],axis=1).values
test_y=test[['quality']].values.ravel()

## splitting this train data into train and validation

train_x,valid_x,train_y,valid_y=train_test_split(train_x,train_y,test_size=0.20,random_state=42)

signature=infer_signature(train_x,train_y)

# %%
np.mean(train_x,axis=0)
# Out:
# array([6.86621852e+00, 2.80377808e-01, 3.32597005e-01, 6.42164738e+00,
#        4.55513955e-02, 3.53556841e+01, 1.38792376e+02, 9.94074221e-01,
#        3.18919333e+00, 4.88396869e-01, 1.05005673e+01])

# %%
train_x.shape[1]
# Out:
# 11

# %%
### ANN Model

def train_model(params,epochs,train_x,train_y,valid_x,valid_y,test_x,test_y):

    ## Define model architecture
    mean=np.mean(train_x,axis=0)
    var=np.var(train_x,axis=0)

    model=keras.Sequential(
        [
            keras.Input([train_x.shape[1]]),
            keras.layers.Normalization(mean=mean,variance=var),
            keras.layers.Dense(64,activation='relu'),
            keras.layers.Dense(1)

        ]
    )

    ## compile the model
    model.compile(optimizer=keras.optimizers.SGD(
        learning_rate=params["lr"],momentum=params["momentum"]
    ),
    loss="mean_squared_error",
    metrics=[keras.metrics.RootMeanSquaredError()]
    )

    ## Train the ANN model with lr and momentum params wwith MLFLOW tracking
    with mlflow.start_run(nested=True):
        model.fit(train_x,train_y,validation_data=(valid_x,valid_y),
                  epochs=epochs,
                  batch_size=64)
        
        ## Evaluate the model
        eval_result=model.evaluate(valid_x,valid_y,batch_size=64)

        eval_rmse=eval_result[1]

        ## Log the parameters and results
        mlflow.log_params(params)
        mlflow.log_metric("eval_rmse",eval_rmse)

        ## log the model

        mlflow.tensorflow.log_model(model,"model",signature=signature)

        return {"loss": eval_rmse, "status": STATUS_OK, "model": model}

# %%
def objective(params):
    # MLflow will track the parameters and results for each run
    result = train_model(
        params,
        epochs=3,
        train_x=train_x,
        train_y=train_y,
        valid_x=valid_x,
        valid_y=valid_y,
        test_x=test_x,
        test_y=test_y,
    )
    return result

# %%
space={
    "lr":hp.loguniform("lr",np.log(1e-5),np.log(1e-1)),
    "momentum":hp.uniform("momentum",0.0,1.0)

}

# %%
mlflow.set_experiment("wine-quality")
with mlflow.start_run():
    # Conduct the hyperparameter search using Hyperopt
    trials=Trials()
    best=fmin(
        fn=objective,
        space=space,
        algo=tpe.suggest,
        max_evals=4,
        trials=trials
    )

    # Fetch the details of the best run
    best_run = sorted(trials.results, key=lambda x: x["loss"])[0]

    # Log the best parameters, loss, and model
    mlflow.log_params(best)
    mlflow.log_metric("eval_rmse", best_run["loss"])
    mlflow.tensorflow.log_model(best_run["model"], "model", signature=signature)

    # Print out the best parameters and corresponding loss
    print(f"Best parameters: {best}")
    print(f"Best eval rmse: {best_run['loss']}")
# Out:
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1:00 1s/step - loss: 43.5429 - root_mean_squared_error: 6.5987
# 12/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 36.9488 - root_mean_squared_error: 6.0701
# 19/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.8001 - root_mean_squared_error: 5.7966
# 28/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.5060 - root_mean_squared_error: 5.4927
# 36/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.0832 - root_mean_squared_error: 5.2557
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.5659 - root_mean_squared_error: 4.9960
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 25.3465 - root_mean_squared_error: 4.9728 - val_loss: 3.3192 - val_root_mean_squared_error: 1.8219
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 2.9024 - root_mean_squared_error: 1.7036
# 10/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9844 - root_mean_squared_error: 1.7265
# 23/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9300 - root_mean_squared_error: 1.7111
# 37/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7805 - root_mean_squared_error: 1.6660
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6832 - root_mean_squared_error: 1.6358 - val_loss: 1.8859 - val_root_mean_squared_error: 1.3733
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 1.8611 - root_mean_squared_error: 1.3642
# 21/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6954 - root_mean_squared_error: 1.3015
# 33/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6728 - root_mean_squared_error: 1.2930
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6727 - root_mean_squared_error: 1.2930 - val_loss: 1.6354 - val_root_mean_squared_error: 1.2788
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 1.3342 - root_mean_squared_error: 1.1551
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6597 - root_mean_squared_error: 1.2872
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - loss: 35.6965 - root_mean_squared_error: 5.9747
#  4/46 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 33.6469 - root_mean_squared_error: 5.7988
#  5/46 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 32.9042 - root_mean_squared_error: 5.7333
#  9/46 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 30.1357 - root_mean_squared_error: 5.4799
# 12/46 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 28.3204 - root_mean_squared_error: 5.3055
# 21/46 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 23.9752 - root_mean_squared_error: 4.8570
# 24/46 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 22.8096 - root_mean_squared_error: 4.7283
# 29/46 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 21.1110 - root_mean_squared_error: 4.5336
# 38/46 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 18.6980 - root_mean_squared_error: 4.2423
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 17.0607 - root_mean_squared_error: 4.0343
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 16.8831 - root_mean_squared_error: 4.0112 - val_loss: 2.2160 - val_root_mean_squared_error: 1.4886
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 1.7034 - root_mean_squared_error: 1.3051
# 11/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6487 - root_mean_squared_error: 1.2837
# 22/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7050 - root_mean_squared_error: 1.3054
# 26/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7329 - root_mean_squared_error: 1.3158
# 30/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7464 - root_mean_squared_error: 1.3210
# 36/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7515 - root_mean_squared_error: 1.3230
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7474 - root_mean_squared_error: 1.3215
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.7459 - root_mean_squared_error: 1.3210 - val_loss: 1.6484 - val_root_mean_squared_error: 1.2839
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 1.6113 - root_mean_squared_error: 1.2694
# 12/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4762 - root_mean_squared_error: 1.2147
# 22/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4615 - root_mean_squared_error: 1.2088
# 33/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4434 - root_mean_squared_error: 1.2012
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4316 - root_mean_squared_error: 1.1963
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4303 - root_mean_squared_error: 1.1958 - val_loss: 1.4074 - val_root_mean_squared_error: 1.1863
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.2196 - root_mean_squared_error: 1.1044
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4400 - root_mean_squared_error: 1.1993
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4375 - root_mean_squared_error: 1.1983
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1:31 2s/step - loss: 39.0645 - root_mean_squared_error: 6.2502
#  6/46 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 35.7385 - root_mean_squared_error: 5.9764
#  8/46 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 34.9298 - root_mean_squared_error: 5.9076
# 14/46 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 32.2543 - root_mean_squared_error: 5.6702
# 23/46 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 28.2770 - root_mean_squared_error: 5.2886
# 33/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 24.5943 - root_mean_squared_error: 4.9017
# 41/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.2934 - root_mean_squared_error: 4.6432
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 20.8739 - root_mean_squared_error: 4.4772 - val_loss: 2.2535 - val_root_mean_squared_error: 1.5012
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 1.2486 - root_mean_squared_error: 1.1174
# 14/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9271 - root_mean_squared_error: 1.3860
# 29/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8704 - root_mean_squared_error: 1.3664
# 43/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8530 - root_mean_squared_error: 1.3603
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8440 - root_mean_squared_error: 1.3571 - val_loss: 1.5460 - val_root_mean_squared_error: 1.2434
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 16s 356ms/step - loss: 1.1306 - root_mean_squared_error: 1.0633
# 16/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3201 - root_mean_squared_error: 1.1485
# 29/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3377 - root_mean_squared_error: 1.1563
# 44/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3384 - root_mean_squared_error: 1.1566
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.3391 - root_mean_squared_error: 1.1570 - val_loss: 1.3188 - val_root_mean_squared_error: 1.1484
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.2070 - root_mean_squared_error: 1.0986
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3296 - root_mean_squared_error: 1.1526
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - loss: 39.9586 - root_mean_squared_error: 6.3213
#  7/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 37.1069 - root_mean_squared_error: 6.0906
# 14/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 36.3835 - root_mean_squared_error: 6.0311
# 20/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 36.2042 - root_mean_squared_error: 6.0164
# 26/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 36.0566 - root_mean_squared_error: 6.0042
# 32/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 35.9109 - root_mean_squared_error: 5.9921
# 37/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 35.7891 - root_mean_squared_error: 5.9820
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 35.5942 - root_mean_squared_error: 5.9656
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 35.5471 - root_mean_squared_error: 5.9617 - val_loss: 32.9982 - val_root_mean_squared_error: 5.7444
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 34.9658 - root_mean_squared_error: 5.9132
# 16/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33.6848 - root_mean_squared_error: 5.8035
# 31/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33.0461 - root_mean_squared_error: 5.7481
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 32.6745 - root_mean_squared_error: 5.7156 - val_loss: 30.3992 - val_root_mean_squared_error: 5.5135
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 18s 417ms/step - loss: 30.0694 - root_mean_squared_error: 5.4836
# 11/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.7906 - root_mean_squared_error: 5.5488
# 26/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.3682 - root_mean_squared_error: 5.5106
# 40/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.0937 - root_mean_squared_error: 5.4856
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 29.9862 - root_mean_squared_error: 5.4757 - val_loss: 28.0172 - val_root_mean_squared_error: 5.2931
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 27.1774 - root_mean_squared_error: 5.2132
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 27.8929 - root_mean_squared_error: 5.2813
#
# 100%|██████████| 4/4 [01:17<00:00, 19.30s/trial, best loss: 1.148401141166687]
# Best parameters: {'lr': np.float64(0.0007787941157038496), 'momentum': np.float64(0.8889074574458754)}
# Best eval rmse: 1.148401141166687

# %%
## Inferencing

from mlflow.models import validate_serving_input

model_uri = 'runs:/287825ab14574483a3ce6d74fd612390/model'

# The logged model does not contain an input_example.
# Manually generate a serving payload to verify your model prior to deployment.
from mlflow.models import convert_input_example_to_serving_input

# Define INPUT_EXAMPLE via assignment with your own input example to the model
# A valid input example is a data instance suitable for pyfunc prediction
serving_payload = convert_input_example_to_serving_input(test_x)

# Validate the serving payload works on the model
validate_serving_input(model_uri, serving_payload)
